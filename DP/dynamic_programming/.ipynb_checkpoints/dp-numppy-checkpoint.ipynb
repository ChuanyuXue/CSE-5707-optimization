# %%
# %load_ext cython

# %%
from os import listdir
from tqdm import tqdm
import time
import numpy as np

# %%
PATH = "../data/large_scale/"
# PATH = "/Users/chuanyu/Code/CSE-5707-optimization/01knapsack/data/customized_dataset/"

# %%
def knapSack(W, wt, val, n):
    val = np.array(val, dtype=np.uint32)
    wt = np.array(wt, dtype=np.uint32)
    K = np.zeros(shape = (n+1, W+1), dtype=np.uint32)
    for i in tqdm(range(n + 1), file):
        for w in range(W + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif wt[i-1] <= w:
                K[i][w] = max(val[i-1] + K[i-1][w-wt[i-1]], K[i-1][w])
            else:
                K[i][w] = K[i-1][w]
    ## OUTPUT THE PATH      
    print('----%s Decision Result----'%file)
    
    w = W
    res = K[n][W]
    for i in range(n, 0, -1):
        if res <= 0:
            break
        if res == K[i - 1][w]:
            continue
        else:
            print(i - 1)
            res = res - val[i - 1]
            w = w - wt[i - 1]
  
    return K[n][W]

# %%
# %%cython -a

# cpdef int knapSack(int[:] wt, int[:] val):
#     DEF n = 100_000
#     DEF W = 49973
#     cdef int K[n + 1][W + 1]
#     cdef int i, w
#     for i in range(n + 1):
#         for w in range(W + 1):
#             if i == 0 or w == 0:
#                 K[i][w] = 0
#             elif wt[i-1] <= w:
#                 K[i][w] = max(val[i-1] + K[i-1][w-wt[i-1]], K[i-1][w])
#             else:
#                 K[i][w] = K[i-1][w]
#     return K[n][w]

# %%
values = []
time_log = []
for file in listdir(PATH):
    start_time = time.time()
    with open(PATH + file, 'r') as f:
        data = f.read().split("\n")
        data = [[int(k) for k in x.split(' ')] for x in data[:-1]]
        capacity = data[-1][0]
        data = data[1:-1]
    val = [x[0] for x in data]
    wt = [x[1] for x in data]
    n = len(val)
    values.append(knapSack(capacity, wt, val, n))
    time_log.append(time.time() - start_time)
# Out:
# knapPI_1_5000_1000_1: 100%|██████████| 5000/5000 [00:01<00:00, 4007.92it/s]
# knapPI_2_100_1000_1: 100%|██████████| 100/100 [00:00<00:00, 750.28it/s]
# knapPI_2_2000_1000_1:   0%|          | 0/2000 [00:00<?, ?it/s]
# knapPI_1_5000_1000_1--------
# 4818
# 4648
# 4544
# 4512
# 4487
# 4152
# 4131
# 4026
# 3795
# 3675
# 3599
# 3584
# 3562
# 3477
# 3398
# 3364
# 3216
# 3215
# 3180
# 3032
# 2966
# 2896
# 2744
# 2720
# 2504
# 2365
# 1904
# 1457
# 1361
# 1322
# 1143
# 830
# 603
# 599
# 216
# 121
# 10
# knapPI_2_100_1000_1--------
# 84
# 70
# 56
# 44
# 37
# 23
# 10
# knapPI_2_2000_1000_1: 100%|██████████| 2000/2000 [00:02<00:00, 925.85it/s]
# knapPI_3_200_1000_1: 100%|██████████| 200/200 [00:00<00:00, 2574.99it/s]
# knapPI_1_500_1000_1:   4%|▍         | 20/501 [00:00<00:02, 197.83it/s]
# knapPI_2_2000_1000_1--------
# 1729
# 1507
# 1485
# 1457
# 1419
# 1400
# 1361
# 1322
# 1260
# 1143
# 1117
# 1099
# 1048
# 945
# 845
# 830
# 743
# 732
# 657
# 643
# 603
# 599
# 539
# 473
# 463
# 426
# 421
# 269
# 249
# 245
# knapPI_3_200_1000_1--------
# 169
# 157
# 147
# 96
# 89
# 46
# 29
# 20
# 12
# knapPI_1_500_1000_1: 100%|██████████| 501/501 [00:02<00:00, 193.10it/s]
# knapPI_1_200_1000_1: 100%|██████████| 200/200 [00:00<00:00, 4113.94it/s]
# knapPI_1_10000_1000_1:   2%|▏         | 164/10000 [00:00<00:06, 1638.06it/s]
# knapPI_1_500_1000_1--------
# 494
# 493
# 480
# 476
# 473
# 469
# 463
# 446
# 426
# 421
# 419
# 382
# 379
# 373
# 362
# 347
# 334
# 281
# 273
# 269
# 254
# 249
# 216
# 215
# 151
# 147
# 146
# 137
# 134
# 121
# 60
# 53
# 48
# 38
# 37
# 32
# 25
# 23
# 13
# 12
# 10
# 6
# knapPI_1_200_1000_1--------
# 146
# 134
# 121
# 53
# 48
# 10
# 6
# knapPI_1_10000_1000_1: 100%|██████████| 10000/10000 [00:05<00:00, 1699.87it/s]
# knapPI_1_2000_1000_1:   9%|▉         | 176/2000 [00:00<00:01, 1752.88it/s]
# knapPI_1_10000_1000_1--------
# 9559
# 9346
# 9272
# 9164
# 9094
# 8774
# 8773
# 8660
# 8579
# 8557
# 8238
# 8110
# 7915
# 7875
# 7810
# 7510
# 7327
# 7117
# 7068
# 7019
# 6644
# 6526
# 6376
# 6347
# 6307
# 6107
# 6096
# 6025
# 5882
# 5693
# 5496
# 5407
# 5274
# 5136
# 5101
# 5079
# 5068
# 5042
# 5008
# 4818
# 4648
# 4544
# 4512
# 4487
# 4152
# 4131
# 4026
# 3795
# 3675
# 3599
# 3584
# 3562
# 3477
# 3398
# 3364
# 3216
# 3215
# 3180
# 3032
# 2966
# 2896
# 2744
# 2720
# 2504
# 2365
# 1904
# 1457
# 1361
# 1322
# 1143
# 830
# 732
# 603
# 599
# 216
# 121
# 10
# knapPI_1_2000_1000_1: 100%|██████████| 2000/2000 [00:01<00:00, 1768.60it/s]
# knapPI_3_1000_1000_1:  53%|█████▎    | 534/1000 [00:00<00:00, 2663.75it/s]
# knapPI_1_2000_1000_1--------
# 1904
# 1873
# 1729
# 1716
# 1672
# 1604
# 1473
# 1472
# 1457
# 1361
# 1333
# 1322
# 1143
# 1057
# 1048
# 830
# 732
# 657
# 603
# 599
# 426
# 419
# 379
# 347
# 216
# 146
# 121
# 10
# knapPI_3_1000_1000_1: 100%|██████████| 1000/1000 [00:00<00:00, 2661.90it/s]
# knapPI_2_5000_1000_1:   3%|▎         | 139/5000 [00:00<00:03, 1388.46it/s]
# knapPI_3_1000_1000_1--------
# 946
# 926
# 883
# 852
# 838
# 767
# 758
# 757
# 721
# 694
# 668
# 637
# 583
# 490
# 432
# 423
# 323
# 273
# 271
# 242
# 169
# 157
# 29
# 20
# knapPI_2_5000_1000_1: 100%|██████████| 5000/5000 [00:03<00:00, 1393.32it/s]
# knapPI_3_500_1000_1:  26%|██▌       | 129/500 [00:00<00:00, 1282.28it/s]
# knapPI_2_5000_1000_1--------
# 4975
# 4818
# 4787
# 4648
# 4512
# 4457
# 4391
# 4214
# 4026
# 3636
# 3599
# 3450
# 3364
# 3216
# 3215
# 3032
# 3023
# 2966
# 2720
# 2685
# 2504
# 2365
# 2146
# 1457
# 1400
# 1361
# 1260
# 1143
# 1048
# 945
# 830
# 732
# 603
# 599
# 539
# 473
# 426
# 421
# 249
# 245
# knapPI_3_500_1000_1: 100%|██████████| 500/500 [00:00<00:00, 1246.40it/s]
# knapPI_2_10000_1000_1:   4%|▍         | 381/10000 [00:00<00:02, 3795.98it/s]
# knapPI_3_500_1000_1--------
# 498
# 490
# 432
# 423
# 391
# 323
# 307
# 292
# 273
# 271
# 268
# 265
# 242
# 211
# 169
# 157
# 106
# 96
# 74
# 29
# 20
# 12
# knapPI_2_10000_1000_1: 100%|██████████| 10000/10000 [00:02<00:00, 3740.77it/s]
# knapPI_3_2000_1000_1:   6%|▌         | 118/2000 [00:00<00:01, 1178.36it/s]
# knapPI_2_10000_1000_1--------
# 9864
# 9422
# 9272
# 9094
# 8774
# 8579
# 8557
# 8169
# 7915
# 7327
# 7117
# 7097
# 7068
# 6590
# 6376
# 6321
# 6096
# 5496
# 5476
# 5274
# 5223
# 5079
# 4648
# 4512
# 4026
# 3636
# 3599
# 3364
# 3216
# 3215
# 3032
# 2720
# 1457
# 1400
# 1361
# 1143
# 830
# 732
# 603
# 599
# 473
# 426
# knapPI_3_2000_1000_1: 100%|██████████| 2000/2000 [00:01<00:00, 1134.09it/s]
# knapPI_3_100_1000_1: 100%|██████████| 100/100 [00:00<00:00, 725.99it/s]
# knapPI_1_1000_1000_1:   0%|          | 0/1000 [00:00<?, ?it/s]
# knapPI_3_2000_1000_1--------
# 1899
# 1849
# 1834
# 1733
# 1731
# 1660
# 1623
# 1615
# 1605
# 1599
# 1474
# 1471
# 1464
# 1463
# 1451
# 1385
# 1351
# 1273
# 1267
# 1261
# 1206
# 1198
# 1193
# 1146
# 946
# 926
# 883
# 852
# 838
# 767
# 757
# 721
# 694
# 668
# 637
# 583
# 490
# 432
# 423
# 323
# 273
# 271
# 242
# 169
# 157
# 29
# 20
# knapPI_3_100_1000_1--------
# 96
# 89
# 85
# 76
# 74
# 70
# 64
# 46
# 29
# 24
# 20
# 12
# 1
# knapPI_1_1000_1000_1: 100%|██████████| 1000/1000 [00:00<00:00, 1432.91it/s]
# knapPI_3_10000_1000_1:   3%|▎         | 263/10000 [00:00<00:03, 2628.00it/s]
# knapPI_1_1000_1000_1--------
# 945
# 830
# 770
# 737
# 732
# 657
# 603
# 599
# 573
# 494
# 473
# 426
# 419
# 382
# 379
# 347
# 281
# 273
# 216
# 146
# 134
# 121
# 48
# 10
# knapPI_3_10000_1000_1: 100%|██████████| 10000/10000 [00:03<00:00, 2621.66it/s]
# knapPI_2_200_1000_1: 100%|██████████| 200/200 [00:00<00:00, 1794.95it/s]
# knapPI_3_5000_1000_1:   0%|          | 0/5000 [00:00<?, ?it/s]
# knapPI_3_10000_1000_1--------
# 9748
# 9296
# 9088
# 9024
# 8974
# 8751
# 8686
# 8452
# 8262
# 8222
# 8205
# 8057
# 7973
# 7929
# 7853
# 7387
# 7350
# 7249
# 7248
# 7198
# 7187
# 7124
# 6995
# 6947
# 6875
# 6796
# 6779
# 6728
# 6575
# 6467
# 6432
# 6430
# 6173
# 6064
# 5932
# 5843
# 5792
# 5721
# 5720
# 5488
# 5483
# 5440
# 5199
# 5093
# 5008
# 4607
# 4579
# 4543
# 4403
# 4205
# 4135
# 4107
# 4105
# 3808
# 3683
# 3575
# 3375
# 3081
# 2914
# 2800
# 2722
# 2683
# 2399
# 2369
# 2286
# 2013
# 2003
# 1660
# 1615
# 1451
# 1267
# 1198
# 946
# 883
# 852
# 721
# 423
# 271
# 29
# 20
# knapPI_2_200_1000_1--------
# 147
# 137
# 70
# 37
# 23
# knapPI_3_5000_1000_1: 100%|██████████| 5000/5000 [00:01<00:00, 3121.35it/s]
# knapPI_2_1000_1000_1:  12%|█▏        | 118/1000 [00:00<00:00, 1166.54it/s]
# knapPI_3_5000_1000_1--------
# 4607
# 4543
# 4403
# 4205
# 4185
# 4135
# 4107
# 4105
# 3808
# 3683
# 3575
# 3427
# 3375
# 3081
# 2914
# 2800
# 2722
# 2683
# 2531
# 2399
# 2369
# 2286
# 2141
# 2013
# 2003
# 1660
# 1615
# 1599
# 1474
# 1471
# 1451
# 1385
# 1267
# 1206
# 1198
# 946
# 883
# 852
# 721
# 637
# 432
# 423
# 323
# 271
# 242
# 29
# 20
# knapPI_2_1000_1000_1: 100%|██████████| 1000/1000 [00:00<00:00, 1168.17it/s]
# knapPI_2_500_1000_1:  12%|█▏        | 61/500 [00:00<00:00, 609.09it/s]
# knapPI_2_1000_1000_1--------
# 945
# 845
# 830
# 775
# 743
# 732
# 669
# 657
# 643
# 603
# 599
# 539
# 473
# 463
# 426
# 421
# 269
# 262
# 249
# 245
# knapPI_2_500_1000_1: 100%|██████████| 500/500 [00:00<00:00, 601.53it/s]
# knapPI_1_100_1000_1: 100%|██████████| 100/100 [00:00<00:00, 4010.43it/s]
# knapPI_2_500_1000_1--------
# 479
# 473
# 469
# 463
# 446
# 426
# 421
# 379
# 292
# 269
# 262
# 249
# 245
# 236
# 211
# 147
# 53
# 37
# 23
# knapPI_1_100_1000_1--------
# 48
# 37
# 23
# 10
# 6

# %%
time_log = sorted(list(zip(listdir(PATH), time_log)), key=lambda x:int(x[0].split('_')[2]))
[print("%.3f"%x) for x in [x[1] for x in sorted(time_log, key=lambda x:int(x[0].split('_')[1]))]]
# Out:
# 0.027
# 0.050
# 2.598
# 0.701
# 1.136
# 1.280
# 5.900
# 0.135
# 0.113
# 0.834
# 0.859
# 2.165
# 3.612
# 2.690
# 0.139
# 0.080
# 0.404
# 0.379
# 1.769
# 1.612
# 3.832
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
result = sorted(list(zip(listdir(PATH), values)), key=lambda x:int(x[0].split('_')[2]))
[print(x[1]) for x in sorted(result, key=lambda x:int(x[0].split('_')[1]))]
# Out:
# Jupyter cannot be started. Error attempting to locate Jupyter: Running cells with 'Python 3.9.2 64-bit' requires notebook package.
#
# Run the following command to install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.

# %%
# Out:
# Jupyter cannot be started. Error attempting to locate Jupyter: Running cells with 'Python 3.9.2 64-bit' requires notebook package.
#
# Run the following command to install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.
